# %% [raw]
# import pandas as pd

# %%
import requests

# %%
### BeautifulSoup is a Python library used for web scraping.
## It helps you parse and extract data from HTML and XML documents easily.

# %%
from bs4 import BeautifulSoup
