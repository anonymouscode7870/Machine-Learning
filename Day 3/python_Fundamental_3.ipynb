# %% [markdown]
# # Conditional Statements

# %% [markdown]
# ## if else

# %%
age = int(input("Enter Your age"))
if age>=18:
    print("You can Vote")
else:
    print("You Cannot Vote")
# Out:
# Enter Your age 2
# You Cannot Vote

# %% [markdown]
# ## elif same as if else
